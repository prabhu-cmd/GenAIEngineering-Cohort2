# %% [markdown]
# ### Groq Usage for LLM ###
# **Library Need**
# To use the APIs provided by the groq platform, the library 'groq' is required.
# Ensure to have performed 'pip install groq'
# The API key from your Groq account would be required to execute this code

# %%
# Import required class from Groq
from groq import Groq
from dotenv import load_dotenv

# Initialise an client object with API key
load_dotenv (dotenv_path="./copy.env")

Client = Groq ()

# Client = Groq (api_key=api_keyy)

# %% [markdown]
# **Invoke for chat Completion**
# >The APIs can be used for invoking LLM models available in Groq for chat completion
# >Try with differet models and different prompt messages

# %%
prompt = "Tell me what is special about 15-Jun"

# Prompt needs to be organised as message (list of dict)
messages=[
    {
        "role": "user",
        "content": prompt,
    }
]
completion = Client.chat.completions.create(
    messages=messages,
    model="llama3-70b-8192",
    # model="llama-3.3-70b-specdec",
    stop=None,
    temperature=1.0
)

print (completion.choices[0].message.content)
# Out:
# June 15th!
#
# There are several special events and observances on this day:
#
# 1. **World Elder Abuse Awareness Day**: This day was designated by the United Nations in 2011 to raise awareness about the abuse, neglect, and exploitation of older people.
# 2. **Day of St. John the Baptist** (also known as Midsummer): This day marks the birthday of John the Baptist, a significant Christian figure. In many European countries, especially in Scandinavian nations, this day is celebrated with midsummer festivals, bonfires, and traditional folk dances.
# 3. **Father's Day** in several countries, including El Salvador, Guatemala, and Panama.
# 4. **National Flag Day** in Denmark, commemorating the adoption of the Danish flag, the Dannebrog, in the 14th century.
# 5. **World Wind Day**, highlighting the importance of wind energy as a sustainable and clean source of power.
# 6. **Global Day of Action Against Illicit Trade**, focusing on combatting illegal trade activities, including counterfeiting, and organized crime.
#
# These are just a few of the special commemorations on this day. Each one highlights a different aspect of human life, from social awareness to cultural celebrations and international cooperation.
